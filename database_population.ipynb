# %%
import sqlite3
conn = sqlite3.connect('sanfrancisco.db')
import datetime

# %%
#change NOT NULL to NULL create function like below to each

c = conn.cursor()
c.execute('''CREATE TABLE IF NOT EXISTS 
"Address" (
    "Address" string  NOT NULL ,
    "City" string  NOT NULL ,
    "State" string  NOT NULL ,
    "Zipcode" int  NOT NULL ,
    "Location" string  NOT NULL ,
    "Original_Price" int  NULL ,
    "Listing_date" int NULL ,
    "Days_on_Market" int NULL ,
    "Sold_Price" int NULL ,
    "Sold_date" int  NOT NULL ,
    "Bedroom" float  NOT NULL ,
    "Bathroom" float  NOT NULL ,
    "Sq_ft" int  NULL ,
    "Latitude" float  NOT NULL ,
    "Longitude" float  NOT NULL ,
    "URL" string  NOT NULL ,
    CONSTRAINT "pk_Address-PK" PRIMARY KEY (
        "Address"
    )
)''')

conn.commit()

# %%
import csv

removed_entries = 0

with open('redfinsold.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter= ',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            #print(f'Coloumn names are {",".join(row)}')
            line_count +=1
        else:
            print(row)
            line_count += 1
            Address=row[3]
            City = row[4]
            State = row[5]
            Zip = int(row[6])
            location = row[10]
            #original_price = null
            #listing_date=
            
            days_on_market = None
            if len(row[14]) > 0:
                days_on_market= int(row[14])
                
            sold_price = None
            if len(row[7]) > 0:
                sold_price = int(row[7])
            else:
                removed_entries += 1
                continue
                
            sold_date = row[1]##come back to
            
            
            bedroom = float(row[8])
            bath= float(row[9])
            
            sq_ft = None
            if len(row[11]) > 0:
                sq_ft = int(row[11])
            
            url=row[20]
            latitude =float(row[-2])
            longitude = float(row[-1])
            print(Address)
            print(City)
            print(State)
            print(Zip)
            print(location)
            print(days_on_market)
            print(sold_price)
            print(sold_date)
            print(bedroom)
            print(bath)
            print(sq_ft)
            print(url)
            print(latitude)
            print(longitude)
            sold_date=int(datetime.datetime.strptime(sold_date,"%B-%d-%Y").strftime("%s"))
            print(sold_date)
            
            c.execute('''INSERT OR REPLACE INTO Address (Address,City,State,Zipcode,Location,
            Days_on_Market,Sold_Price,Sold_date,Bedroom,Bathroom,Sq_ft,Latitude,Longitude,URL) 
            VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?)
            ''', (Address,City,State,Zip,location,days_on_market,sold_price,sold_date,bedroom,bath,sq_ft,latitude,longitude,url))
            conn.commit()

            
print("Removed " + str(removed_entries) + " entries...")
# Out:
# ['PAST SALE', 'April-5-2019', 'Single Family Residential', '31 Romain St', 'San Francisco', 'CA', '94114', '2290000', '3', '3.0', 'Eureka Valley/Dolore', '2155', '2500', '1906', '20', '1063', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/31-Romain-St-94114/home/1316364', 'San Francisco MLS', '480612', 'N', 'Y', '37.7563136', '-122.4395799']
# 31 Romain St
# San Francisco
# CA
# 94114
# Eureka Valley/Dolore
# 20
# 2290000
# April-5-2019
# 3.0
# 3.0
# 2155
# http://www.redfin.com/CA/San-Francisco/31-Romain-St-94114/home/1316364
# 37.7563136
# -122.4395799
# 1554447600
# ['PAST SALE', 'February-4-2019', 'Single Family Residential', '3220 Jennings St', 'San Francisco', 'CA', '94124', '849000', '5', '3.0', 'Bayview Heights', '1464', '2247', '1915', '80', '580', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/3220-Jennings-St-94124/home/1856008', 'San Francisco MLS', '479331', 'N', 'Y', '37.7199943', '-122.3953455']
# 3220 Jennings St
# San Francisco
# CA
# 94124
# Bayview Heights
# 80
# 849000
# February-4-2019
# 5.0
# 3.0
# 1464
# http://www.redfin.com/CA/San-Francisco/3220-Jennings-St-94124/home/1856008
# 37.7199943
# -122.3953455
# 1549267200
# ['PAST SALE', 'January-31-2019', 'Single Family Residential', '545 Wilde', 'San Francisco', 'CA', '94134', '1130000', '5', '3.0', 'Visitacion Valley', '2707', '3750', '1945', '84', '417', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/545-Wilde-Ave-94134/home/1606551', 'San Francisco MLS', '478893', 'N', 'Y', '37.717913737311335', '-122.40817065378782']
# 545 Wilde
# San Francisco
# CA
# 94134
# Visitacion Valley
# 84
# 1130000
# January-31-2019
# 5.0
# 3.0
# 2707
# http://www.redfin.com/CA/San-Francisco/545-Wilde-Ave-94134/home/1606551
# 37.717913737311335
# -122.40817065378782
# 1548921600
# ['PAST SALE', 'February-15-2019', 'Single Family Residential', '1951 Webster St', 'San Francisco', 'CA', '94115', '3300000', '3', '3.5', 'Lower Pacific Height', '', '', '', '69', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1951-Webster-St-94115/home/571675', 'San Francisco MLS', '478882', 'N', 'Y', '37.7888203', '-122.4322807']
# 1951 Webster St
# San Francisco
# CA
# 94115
# Lower Pacific Height
# 69
# 3300000
# February-15-2019
# 3.0
# 3.5
# None
# http://www.redfin.com/CA/San-Francisco/1951-Webster-St-94115/home/571675
# 37.7888203
# -122.4322807
# 1550217600
# ['PAST SALE', 'April-22-2019', 'Single Family Residential', '930 Noe St', 'San Francisco', 'CA', '94114', '3600000', '4', '3.5', 'Noe Valley', '2750', '2500', '1905', '3', '1309', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/930-Noe-St-94114/home/715659', 'San Francisco MLS', '482845', 'N', 'Y', '37.7541524', '-122.4323249']
# 930 Noe St
# San Francisco
# CA
# 94114
# Noe Valley
# 3
# 3600000
# April-22-2019
# 4.0
# 3.5
# 2750
# http://www.redfin.com/CA/San-Francisco/930-Noe-St-94114/home/715659
# 37.7541524
# -122.4323249
# 1555916400
# ['PAST SALE', 'March-7-2019', 'Single Family Residential', '233 Dellbrook', 'San Francisco', 'CA', '94131', '1670000', '4', '2.0', 'Midtown Terrace', '1818', '3380', '1956', '49', '919', '18', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/233-Dellbrook-Ave-94131/home/680651', 'San Francisco MLS', '479854', 'N', 'Y', '37.749897', '-122.4532922']
# 233 Dellbrook
# San Francisco
# CA
# 94131
# Midtown Terrace
# 49
# 1670000
# March-7-2019
# 4.0
# 2.0
# 1818
# http://www.redfin.com/CA/San-Francisco/233-Dellbrook-Ave-94131/home/680651
# 37.749897
# -122.4532922
# 1551945600
# ['PAST SALE', 'March-15-2019', 'Single Family Residential', '1230 5th Ave', 'SAN FRANCISCO', 'CA', '94122', '2325000', '4', '2.0', 'SAN FRANCISCO', '1932', '3000', '1908', '41', '1203', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1230-5th-Ave-94122/home/626847', 'MLSListings', 'ML81740897', 'N', 'Y', '37.7656473', '-122.46195']
# 1230 5th Ave
# SAN FRANCISCO
# CA
# 94122
# SAN FRANCISCO
# 41
# 2325000
# March-15-2019
# 4.0
# 2.0
# 1932
# http://www.redfin.com/CA/San-Francisco/1230-5th-Ave-94122/home/626847
# 37.7656473
# -122.46195
# 1552633200
# ['PAST SALE', 'March-1-2019', 'Single Family Residential', '1 Marcela Ave', 'San Francisco', 'CA', '94116', '1900000', '4', '3.5', 'Forest Hill', '3753', '4726', '1917', '55', '506', '41', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1-Marcela-Ave-94116/home/1211935', 'San Francisco MLS', '481229', 'N', 'Y', '37.7488505', '-122.4607116']
# 1 Marcela Ave
# San Francisco
# CA
# 94116
# Forest Hill
# 55
# 1900000
# March-1-2019
# 4.0
# 3.5
# 3753
# http://www.redfin.com/CA/San-Francisco/1-Marcela-Ave-94116/home/1211935
# 37.7488505
# -122.4607116
# 1551427200
# ['PAST SALE', 'March-29-2019', 'Single Family Residential', '1362 7th Ave', 'San Francisco', 'CA', '94122', '3850000', '5', '6.5', 'Inner Sunset', '3854', '2996', '', '27', '999', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1362-7th-Ave-94122/home/628764', 'San Francisco MLS', '481425', 'N', 'Y', '37.7629824', '-122.4638959']
# 1362 7th Ave
# San Francisco
# CA
# 94122
# Inner Sunset
# 27
# 3850000
# March-29-2019
# 5.0
# 6.5
# 3854
# http://www.redfin.com/CA/San-Francisco/1362-7th-Ave-94122/home/628764
# 37.7629824
# -122.4638959
# 1553842800
# ['PAST SALE', 'April-1-2019', 'Single Family Residential', '289 San Marcos Ave', 'San Francisco', 'CA', '94116', '2450000', '5', '4.0', 'Forest Hill', '4042', '5248', '1978', '24', '606', '46', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/289-San-Marcos-Ave-94116/home/1938803', 'San Francisco MLS', '481805', 'N', 'Y', '37.7462846', '-122.4669585']
# 289 San Marcos Ave
# San Francisco
# CA
# 94116
# Forest Hill
# 24
# 2450000
# April-1-2019
# 5.0
# 4.0
# 4042
# http://www.redfin.com/CA/San-Francisco/289-San-Marcos-Ave-94116/home/1938803
# 37.7462846
# -122.4669585
# 1554102000
# ['PAST SALE', 'April-12-2019', 'Single Family Residential', '1471 10th Ave', 'San Francisco', 'CA', '94122', '2350000', '3', '2.5', 'Inner Sunset', '2050', '2996', '1916', '13', '1146', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1471-10th-Ave-94122/home/1324771', 'San Francisco MLS', '482325', 'N', 'Y', '37.7608142', '-122.4674008']
# 1471 10th Ave
# San Francisco
# CA
# 94122
# Inner Sunset
# 13
# 2350000
# April-12-2019
# 3.0
# 2.5
# 2050
# http://www.redfin.com/CA/San-Francisco/1471-10th-Ave-94122/home/1324771
# 37.7608142
# -122.4674008
# 1555052400
# ['PAST SALE', 'April-23-2019', 'Single Family Residential', '18 Olympia Way', 'San Francisco', 'CA', '94131', '1510000', '3', '2.0', 'Midtown Terrace', '1270', '3571', '1957', '2', '1189', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/18-Olympia-Way-94131/home/1944004', 'San Francisco MLS', '482523', 'N', 'Y', '37.7513942', '-122.4525403']
# 18 Olympia Way
# San Francisco
# CA
# 94131
# Midtown Terrace
# 2
# 1510000
# April-23-2019
# 3.0
# 2.0
# 1270
# http://www.redfin.com/CA/San-Francisco/18-Olympia-Way-94131/home/1944004
# 37.7513942
# -122.4525403
# 1556002800
# ['PAST SALE', 'March-14-2019', 'Single Family Residential', '655 Marina Blvd', 'San Francisco', 'CA', '94123', '4125000', '5', '4.0', 'Marina', '3395', '', '1935', '42', '1215', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/655-Marina-Blvd-94123/home/1515059', 'San Francisco MLS', '474942', 'N', 'Y', '37.8052813', '-122.4446953']
# 655 Marina Blvd
# San Francisco
# CA
# 94123
# Marina
# 42
# 4125000
# March-14-2019
# 5.0
# 4.0
# 3395
# http://www.redfin.com/CA/San-Francisco/655-Marina-Blvd-94123/home/1515059
# 37.8052813
# -122.4446953
# 1552546800
# ['PAST SALE', 'April-23-2019', 'Single Family Residential', '3001 Pacific Ave', 'San Francisco', 'CA', '94115', '15850000', '8', '6.5', 'Pacific Heights', '13643', '8106', '1906', '2', '1162', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/3001-Pacific-Ave-94115/home/587453', 'San Francisco MLS', '466764', 'N', 'Y', '37.7918514', '-122.4447997']
# 3001 Pacific Ave
# San Francisco
# CA
# 94115
# Pacific Heights
# 2
# 15850000
# April-23-2019
# 8.0
# 6.5
# 13643
# http://www.redfin.com/CA/San-Francisco/3001-Pacific-Ave-94115/home/587453
# 37.7918514
# -122.4447997
# 1556002800
# ['PAST SALE', 'February-19-2019', 'Single Family Residential', '4348 21st St', 'San Francisco', 'CA', '94114', '1690000', '3', '2.0', 'Eureka Valley/Dolore', '1450', '2949', '1925', '65', '1166', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/4348-21st-St-94114/home/1819999', 'San Francisco MLS', '480019', 'N', 'Y', '37.7554673', '-122.4396684']
# 4348 21st St
# San Francisco
# CA
# 94114
# Eureka Valley/Dolore
# 65
# 1690000
# February-19-2019
# 3.0
# 2.0
# 1450
# http://www.redfin.com/CA/San-Francisco/4348-21st-St-94114/home/1819999
# 37.7554673
# -122.4396684
# 1550563200
# ['PAST SALE', 'March-21-2019', 'Single Family Residential', '143 Collingwood St', 'San Francisco', 'CA', '94114', '3150000', '4', '4.0', 'Eureka Valley/Dolore', '2895', '3125', '1929', '35', '1088', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/143-Collingwood-St-94114/home/1921908', 'San Francisco MLS', '481043', 'N', 'Y', '37.760081', '-122.435751']
# 143 Collingwood St
# San Francisco
# CA
# 94114
# Eureka Valley/Dolore
# 35
# 3150000
# March-21-2019
# 4.0
# 4.0
# 2895
# http://www.redfin.com/CA/San-Francisco/143-Collingwood-St-94114/home/1921908
# 37.760081
# -122.435751
# 1553151600
# ['PAST SALE', 'March-22-2019', 'Single Family Residential', '1134 Castro St', 'San Francisco', 'CA', '94114', '2550000', '4', '3.0', 'Noe Valley', '2550', '2495', '1900', '34', '1000', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1134-Castro-St-94114/home/973134', 'San Francisco MLS', '481747', 'N', 'Y', '37.752373', '-122.434504']
# 1134 Castro St
# San Francisco
# CA
# 94114
# Noe Valley
# 34
# 2550000
# March-22-2019
# 4.0
# 3.0
# 2550
# http://www.redfin.com/CA/San-Francisco/1134-Castro-St-94114/home/973134
# 37.752373
# -122.434504
# 1553238000
# ['PAST SALE', 'February-9-2019', 'Single Family Residential', '1145 Vallejo St', 'San Francisco', 'CA', '94109', '2575000', '4', '3.5', 'Russian Hill', '2026', '1200', '1907', '75', '1271', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1145-Vallejo-St-94109/home/1941450', 'San Francisco MLS', '475775', 'N', 'Y', '37.797478', '-122.416127']
# 1145 Vallejo St
# San Francisco
# CA
# 94109
# Russian Hill
# 75
# 2575000
# February-9-2019
# 4.0
# 3.5
# 2026
# http://www.redfin.com/CA/San-Francisco/1145-Vallejo-St-94109/home/1941450
# 37.797478
# -122.416127
# 1549699200
# ['PAST SALE', 'March-19-2019', 'Single Family Residential', '2973 Pine St', 'San Francisco', 'CA', '94115', '4650000', '5', '3.5', 'Lower Pacific Height', '3584', '', '', '37', '1297', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2973-Pine-St-94115/home/1419550', 'San Francisco MLS', '482969', 'N', 'Y', '37.7863851', '-122.444667']
# 2973 Pine St
# San Francisco
# CA
# 94115
# Lower Pacific Height
# 37
# 4650000
# March-19-2019
# 5.0
# 3.5
# 3584
# http://www.redfin.com/CA/San-Francisco/2973-Pine-St-94115/home/1419550
# 37.7863851
# -122.444667
# 1552978800
# ['PAST SALE', 'February-13-2019', 'Single Family Residential', '844 Duncan St', 'San Francisco', 'CA', '94131', '4500000', '4', '4.5', 'Noe Valley', '', '2953', '', '71', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/844-Duncan-St-94131/home/1664574', 'San Francisco MLS', '480269', 'N', 'Y', '37.7455853', '-122.4388721']
# 844 Duncan St
# San Francisco
# CA
# 94131
# Noe Valley
# 71
# 4500000
# February-13-2019
# 4.0
# 4.5
# None
# http://www.redfin.com/CA/San-Francisco/844-Duncan-St-94131/home/1664574
# 37.7455853
# -122.4388721
# 1550044800
# ['PAST SALE', 'March-6-2019', 'Single Family Residential', '822 Duncan', 'San Francisco', 'CA', '94114', '2595000', '4', '3.0', 'Noe Valley', '2320', '3040', '1947', '50', '1119', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/822-Duncan-St-94131/home/1982410', 'San Francisco MLS', '480368', 'N', 'Y', '37.7455824', '-122.4385182']
# 822 Duncan
# San Francisco
# CA
# 94114
# Noe Valley
# 50
# 2595000
# March-6-2019
# 4.0
# 3.0
# 2320
# http://www.redfin.com/CA/San-Francisco/822-Duncan-St-94131/home/1982410
# 37.7455824
# -122.4385182
# 1551859200
# ['PAST SALE', 'March-29-2019', 'Single Family Residential', '17 Newburg St', 'San Francisco', 'CA', '94131', '1965000', '3', '2.0', 'Noe Valley', '', '1920', '1944', '27', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/17-Newburg-St-94131/home/1856861', 'San Francisco MLS', '481777', 'N', 'Y', '37.7461676', '-122.4338622']
# 17 Newburg St
# San Francisco
# CA
# 94131
# Noe Valley
# 27
# 1965000
# March-29-2019
# 3.0
# 2.0
# None
# http://www.redfin.com/CA/San-Francisco/17-Newburg-St-94131/home/1856861
# 37.7461676
# -122.4338622
# 1553842800
# ['PAST SALE', 'April-5-2019', 'Single Family Residential', '1328 Noe St', 'San Francisco', 'CA', '94131', '2700000', '3', '3.0', 'Noe Valley', '1745', '2237', '1907', '20', '1547', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1328-Noe-St-94131/home/805198', 'San Francisco MLS', '482004', 'N', 'Y', '37.747713', '-122.431712']
# 1328 Noe St
# San Francisco
# CA
# 94131
# Noe Valley
# 20
# 2700000
# April-5-2019
# 3.0
# 3.0
# 1745
# http://www.redfin.com/CA/San-Francisco/1328-Noe-St-94131/home/805198
# 37.747713
# -122.431712
# 1554447600
# ['PAST SALE', 'January-28-2019', 'Single Family Residential', '87 Melrose Ave', 'San Francisco', 'CA', '94131', '1590000', '4', '3.0', 'San Francisco County', '2467', '2496', '1941', '87', '645', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/87-Melrose-Ave-94131/home/1814008', 'BAREIS', '21822629', 'N', 'Y', '37.7336548', '-122.4440034']
# 87 Melrose Ave
# San Francisco
# CA
# 94131
# San Francisco County
# 87
# 1590000
# January-28-2019
# 4.0
# 3.0
# 2467
# http://www.redfin.com/CA/San-Francisco/87-Melrose-Ave-94131/home/1814008
# 37.7336548
# -122.4440034
# 1548662400
# ['PAST SALE', 'February-28-2019', 'Single Family Residential', '297 Capistrano Ave', 'San Francisco', 'CA', '94112', '1180000', '3', '2.0', 'Mission Terrace', '1490', '3898', '1925', '56', '792', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/297-Capistrano-Ave-94112/home/1387234', 'San Francisco MLS', '477925', 'N', 'Y', '37.7266199', '-122.437838']
# 297 Capistrano Ave
# San Francisco
# CA
# 94112
# Mission Terrace
# 56
# 1180000
# February-28-2019
# 3.0
# 2.0
# 1490
# http://www.redfin.com/CA/San-Francisco/297-Capistrano-Ave-94112/home/1387234
# 37.7266199
# -122.437838
# 1551340800
# ['PAST SALE', 'March-5-2019', 'Single Family Residential', '2301 Diamond St', 'San Francisco', 'CA', '94131', '2000000', '4', '3.5', 'Glen Park', '3540', '2549', '2001', '51', '565', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2301-Diamond-St-94131/home/856118', 'San Francisco MLS', '480267', 'N', 'Y', '37.7381983', '-122.4371027']
# 2301 Diamond St
# San Francisco
# CA
# 94131
# Glen Park
# 51
# 2000000
# March-5-2019
# 4.0
# 3.5
# 3540
# http://www.redfin.com/CA/San-Francisco/2301-Diamond-St-94131/home/856118
# 37.7381983
# -122.4371027
# 1551772800
# ['PAST SALE', 'April-5-2019', 'Single Family Residential', '201 Berkeley Way', 'San Francisco', 'CA', '94131', '2100000', '3', '2.5', 'Diamond Heights', '1904', '3898', '1975', '20', '1103', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/201-Berkeley-Way-94131/home/1186707', 'San Francisco MLS', '481814', 'N', 'Y', '37.7402018', '-122.4396684']
# 201 Berkeley Way
# San Francisco
# CA
# 94131
# Diamond Heights
# 20
# 2100000
# April-5-2019
# 3.0
# 2.5
# 1904
# http://www.redfin.com/CA/San-Francisco/201-Berkeley-Way-94131/home/1186707
# 37.7402018
# -122.4396684
# 1554447600
# ['PAST SALE', 'February-26-2019', 'Single Family Residential', '63 Park Hill Ave', 'San Francisco', 'CA', '94117', '4085000', '4', '3.5', 'Buena Vista Park', '2716', '5519', '1953', '58', '1504', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/63-Park-Hill-Ave-94117/home/992836', 'San Francisco MLS', '480849', 'N', 'Y', '37.7671643', '-122.4389164']
# 63 Park Hill Ave
# San Francisco
# CA
# 94117
# Buena Vista Park
# 58
# 4085000
# February-26-2019
# 4.0
# 3.5
# 2716
# http://www.redfin.com/CA/San-Francisco/63-Park-Hill-Ave-94117/home/992836
# 37.7671643
# -122.4389164
# 1551168000
# ['PAST SALE', 'March-22-2019', 'Single Family Residential', '4388 17th St', 'San Francisco', 'CA', '94114', '2700000', '3', '2.5', 'Corona Heights', '2331', '2186', '1925', '34', '1158', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/4388-17th-St-94114/home/669547', 'San Francisco MLS', '481608', 'N', 'Y', '37.7621052', '-122.4429707']
# 4388 17th St
# San Francisco
# CA
# 94114
# Corona Heights
# 34
# 2700000
# March-22-2019
# 3.0
# 2.5
# 2331
# http://www.redfin.com/CA/San-Francisco/4388-17th-St-94114/home/669547
# 37.7621052
# -122.4429707
# 1553238000
# ['PAST SALE', 'March-6-2019', 'Single Family Residential', '526 Chenery St', 'San Francisco', 'CA', '94131', '1700000', '3', '2.0', 'Glen Park', '1258', '2500', '1922', '50', '1351', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/526-Chenery-St-94131/home/1760565', 'San Francisco MLS', '480752', 'N', 'Y', '37.7353092', '-122.4309977']
# 526 Chenery St
# San Francisco
# CA
# 94131
# Glen Park
# 50
# 1700000
# March-6-2019
# 3.0
# 2.0
# 1258
# http://www.redfin.com/CA/San-Francisco/526-Chenery-St-94131/home/1760565
# 37.7353092
# -122.4309977
# 1551859200
# ['PAST SALE', 'March-13-2019', 'Single Family Residential', '38 Surrey St', 'San Francisco', 'CA', '94131', '3225000', '4', '3.5', 'Glen Park', '3492', '2025', '2010', '43', '924', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/38-Surrey-St-94131/home/35626672', 'San Francisco MLS', '481049', 'N', 'Y', '37.735504', '-122.4331566']
# 38 Surrey St
# San Francisco
# CA
# 94131
# Glen Park
# 43
# 3225000
# March-13-2019
# 4.0
# 3.5
# 3492
# http://www.redfin.com/CA/San-Francisco/38-Surrey-St-94131/home/35626672
# 37.735504
# -122.4331566
# 1552460400
# ['PAST SALE', 'April-12-2019', 'Single Family Residential', '5544 Diamond Heights Blvd', 'San Francisco', 'CA', '94131', '1495000', '3', '2.0', 'Diamond Heights', '1776', '2752', '1968', '13', '842', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/5544-Diamond-Heights-Blvd-94131/home/1880699', 'San Francisco MLS', '480084', 'N', 'Y', '37.7391018', '-122.4367377']
# 5544 Diamond Heights Blvd
# San Francisco
# CA
# 94131
# Diamond Heights
# 13
# 1495000
# April-12-2019
# 3.0
# 2.0
# 1776
# http://www.redfin.com/CA/San-Francisco/5544-Diamond-Heights-Blvd-94131/home/1880699
# 37.7391018
# -122.4367377
# 1555052400
# ['PAST SALE', 'March-26-2019', 'Single Family Residential', '4121 23rd St', 'San Francisco', 'CA', '94114', '2813000', '4', '2.5', 'Noe Valley', '', '1600', '1912', '30', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/4121-23rd-St-94114/home/1590331', 'San Francisco MLS', '483171', 'N', 'Y', '37.7527483', '-122.4346665']
# 4121 23rd St
# San Francisco
# CA
# 94114
# Noe Valley
# 30
# 2813000
# March-26-2019
# 4.0
# 2.5
# None
# http://www.redfin.com/CA/San-Francisco/4121-23rd-St-94114/home/1590331
# 37.7527483
# -122.4346665
# 1553583600
# ['PAST SALE', 'March-12-2019', 'Single Family Residential', '1717 Revere Ave', 'San Francisco', 'CA', '94124', '1430000', '4', '3.0', 'Bayview', '2900', '2469', '1900', '44', '493', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1717-Revere-Ave-94124/home/1335955', 'San Francisco MLS', '479043', 'N', 'Y', '37.7326531', '-122.3923693']
# 1717 Revere Ave
# San Francisco
# CA
# 94124
# Bayview
# 44
# 1430000
# March-12-2019
# 4.0
# 3.0
# 2900
# http://www.redfin.com/CA/San-Francisco/1717-Revere-Ave-94124/home/1335955
# 37.7326531
# -122.3923693
# 1552374000
# ['PAST SALE', 'January-31-2019', 'Single Family Residential', '236 Holladay Ave', 'San Francisco', 'CA', '94110', '1400000', '3', '2.0', 'Bernal Heights', '1050', '1746', '1965', '84', '1333', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/236-Holladay-Ave-94110/home/1971467', 'San Francisco MLS', '479462', 'N', 'Y', '37.7458678', '-122.4055236']
# 236 Holladay Ave
# San Francisco
# CA
# 94110
# Bernal Heights
# 84
# 1400000
# January-31-2019
# 3.0
# 2.0
# 1050
# http://www.redfin.com/CA/San-Francisco/236-Holladay-Ave-94110/home/1971467
# 37.7458678
# -122.4055236
# 1548921600
# ['PAST SALE', 'April-5-2019', 'Single Family Residential', '365 Clipper St', 'San Francisco', 'CA', '94114', '2225000', '4', '2.0', 'Noe Valley', '1755', '2561', '1889', '20', '1268', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/365-Clipper-St-94114/home/1504149', 'San Francisco MLS', '481613', 'N', 'Y', '37.7487593', '-122.4330328']
# 365 Clipper St
# San Francisco
# CA
# 94114
# Noe Valley
# 20
# 2225000
# April-5-2019
# 4.0
# 2.0
# 1755
# http://www.redfin.com/CA/San-Francisco/365-Clipper-St-94114/home/1504149
# 37.7487593
# -122.4330328
# 1554447600
# ['PAST SALE', 'March-18-2019', 'Single Family Residential', '1953 Webster St', 'San Francisco', 'CA', '94115', '3300000', '3', '3.5', 'Lower Pacific Height', '', '1423', '', '38', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1953-Webster-St-94115/home/571667', 'San Francisco MLS', '480622', 'N', 'Y', '37.7888465', '-122.432379']
# 1953 Webster St
# San Francisco
# CA
# 94115
# Lower Pacific Height
# 38
# 3300000
# March-18-2019
# 3.0
# 3.5
# None
# http://www.redfin.com/CA/San-Francisco/1953-Webster-St-94115/home/571667
# 37.7888465
# -122.432379
# 1552892400
# ['PAST SALE', 'February-11-2019', 'Single Family Residential', '94 Stanton St', 'San Francisco', 'CA', '94114', '1550000', '3', '2.0', 'Eureka Valley/Dolore', '1300', '1572', '1952', '73', '1192', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/94-Stanton-St-94114/home/1360827', 'San Francisco MLS', '479900', 'N', 'Y', '37.756912', '-122.442228']
# 94 Stanton St
# San Francisco
# CA
# 94114
# Eureka Valley/Dolore
# 73
# 1550000
# February-11-2019
# 3.0
# 2.0
# 1300
# http://www.redfin.com/CA/San-Francisco/94-Stanton-St-94114/home/1360827
# 37.756912
# -122.442228
# 1549872000
# ['PAST SALE', 'March-21-2019', 'Single Family Residential', '923 Edinburgh St', 'San Francisco', 'CA', '94112', '1800000', '4', '4.5', 'Excelsior', '2319', '2511', '1921', '35', '776', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/923-Edinburgh-St-94112/home/790314', 'San Francisco MLS', '481133', 'N', 'Y', '37.7152933', '-122.4361626']
# 923 Edinburgh St
# San Francisco
# CA
# 94112
# Excelsior
# 35
# 1800000
# March-21-2019
# 4.0
# 4.5
# 2319
# http://www.redfin.com/CA/San-Francisco/923-Edinburgh-St-94112/home/790314
# 37.7152933
# -122.4361626
# 1553151600
# ['PAST SALE', 'April-5-2019', 'Single Family Residential', '369 Cumberland St', 'San Francisco', 'CA', '94114', '7400000', '5', '4.5', 'Eureka Valley/Dolore', '3560', '2848', '', '20', '2079', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/369-Cumberland-St-94114/home/1800752', 'San Francisco MLS', '483237', 'N', 'Y', '37.758466', '-122.4318272']
# 369 Cumberland St
# San Francisco
# CA
# 94114
# Eureka Valley/Dolore
# 20
# 7400000
# April-5-2019
# 5.0
# 4.5
# 3560
# http://www.redfin.com/CA/San-Francisco/369-Cumberland-St-94114/home/1800752
# 37.758466
# -122.4318272
# 1554447600
# ['PAST SALE', 'February-26-2019', 'Single Family Residential', '108 Villa Ter', 'San Francisco', 'CA', '94114', '2870000', '4', '3.5', 'Clarendon Heights', '3134', '3746', '1938', '58', '916', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/108-Villa-Ter-94114/home/1280595', 'San Francisco MLS', '480176', 'N', 'Y', '37.7582778', '-122.4467459']
# 108 Villa Ter
# San Francisco
# CA
# 94114
# Clarendon Heights
# 58
# 2870000
# February-26-2019
# 4.0
# 3.5
# 3134
# http://www.redfin.com/CA/San-Francisco/108-Villa-Ter-94114/home/1280595
# 37.7582778
# -122.4467459
# 1551168000
# ['PAST SALE', 'February-22-2019', 'Single Family Residential', '1224 Quesada Ave', 'San Francisco', 'CA', '94124', '1000000', '3', '2.0', 'Bayview', '1250', '2495', '1941', '62', '800', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1224-Quesada-Ave-94124/home/965824', 'San Francisco MLS', '479741', 'N', 'Y', '37.7284691', '-122.3824555']
# 1224 Quesada Ave
# San Francisco
# CA
# 94124
# Bayview
# 62
# 1000000
# February-22-2019
# 3.0
# 2.0
# 1250
# http://www.redfin.com/CA/San-Francisco/1224-Quesada-Ave-94124/home/965824
# 37.7284691
# -122.3824555
# 1550822400
# ['PAST SALE', 'February-28-2019', 'Single Family Residential', '1754 La Salle', 'San Francisco', 'CA', '94124', '1225000', '5', '3.0', 'Bayview', '1770', '2500', '1955', '56', '692', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1754-La-Salle-Ave-94124/home/144231048', 'San Francisco MLS', '479830', 'N', 'Y', '37.7382917', '-122.3914534']
# 1754 La Salle
# San Francisco
# CA
# 94124
# Bayview
# 56
# 1225000
# February-28-2019
# 5.0
# 3.0
# 1770
# http://www.redfin.com/CA/San-Francisco/1754-La-Salle-Ave-94124/home/144231048
# 37.7382917
# -122.3914534
# 1551340800
# ['PAST SALE', '', 'Single Family Residential', '58 Apollo St', 'San Francisco', 'CA', '94124', '', '3', '2.0', '', '1612', '2587', '1941', '', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/58-Apollo-St-94124/home/1862336', 'San Francisco MLS', '', 'N', 'Y', '37.7321571', '-122.3981999']
# ['PAST SALE', 'February-27-2019', 'Single Family Residential', '1205 San Bruno Ave', 'San Francisco', 'CA', '94110', '2168000', '4', '4.0', 'Inner Mission', '2259', '2495', '1900', '57', '960', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1205-San-Bruno-Ave-94110/home/896813', 'San Francisco MLS', '480287', 'N', 'Y', '37.7542393', '-122.404185']
# 1205 San Bruno Ave
# San Francisco
# CA
# 94110
# Inner Mission
# 57
# 2168000
# February-27-2019
# 4.0
# 4.0
# 2259
# http://www.redfin.com/CA/San-Francisco/1205-San-Bruno-Ave-94110/home/896813
# 37.7542393
# -122.404185
# 1551254400
# ['PAST SALE', 'March-22-2019', 'Single Family Residential', '1152 De Haro St', 'San Francisco', 'CA', '94107', '1780000', '3', '3.0', 'Potrero Hill', '1871', '2500', '1962', '34', '951', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1152-De-Haro-St-94107/home/734422', 'San Francisco MLS', '480910', 'N', 'Y', '37.7553063', '-122.4009546']
# 1152 De Haro St
# San Francisco
# CA
# 94107
# Potrero Hill
# 34
# 1780000
# March-22-2019
# 3.0
# 3.0
# 1871
# http://www.redfin.com/CA/San-Francisco/1152-De-Haro-St-94107/home/734422
# 37.7553063
# -122.4009546
# 1553238000
# ['PAST SALE', 'March-6-2019', 'Single Family Residential', '326 Capp St', 'San Francisco', 'CA', '94110', '3600000', '4', '3.0', 'Inner Mission', '3847', '3675', '1900', '50', '936', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/326-Capp-St-94110/home/906098', 'San Francisco MLS', '481035', 'N', 'Y', '37.7614267', '-122.4184771']
# 326 Capp St
# San Francisco
# CA
# 94110
# Inner Mission
# 50
# 3600000
# March-6-2019
# 4.0
# 3.0
# 3847
# http://www.redfin.com/CA/San-Francisco/326-Capp-St-94110/home/906098
# 37.7614267
# -122.4184771
# 1551859200
# ['PAST SALE', 'April-11-2019', 'Single Family Residential', '12 Esquina Dr', 'San Francisco', 'CA', '94134', '995000', '4', '2.0', 'Visitacion Valley', '1581', '1999', '1945', '14', '629', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/12-Esquina-Dr-94134/home/1856759', 'San Francisco MLS', '481968', 'N', 'Y', '37.7099352', '-122.4212977']
# 12 Esquina Dr
# San Francisco
# CA
# 94134
# Visitacion Valley
# 14
# 995000
# April-11-2019
# 4.0
# 2.0
# 1581
# http://www.redfin.com/CA/San-Francisco/12-Esquina-Dr-94134/home/1856759
# 37.7099352
# -122.4212977
# 1554966000
# ['PAST SALE', 'March-1-2019', 'Single Family Residential', '910 Mansell St', 'San Francisco', 'CA', '94134', '1550000', '3', '2.5', 'Portola', '1715', '2500', '1963', '55', '904', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/910-Mansell-St-94134/home/1371602', 'San Francisco MLS', '480174', 'N', 'Y', '37.7193646', '-122.4104353']
# 910 Mansell St
# San Francisco
# CA
# 94134
# Portola
# 55
# 1550000
# March-1-2019
# 3.0
# 2.5
# 1715
# http://www.redfin.com/CA/San-Francisco/910-Mansell-St-94134/home/1371602
# 37.7193646
# -122.4104353
# 1551427200
# ['PAST SALE', 'February-5-2019', 'Single Family Residential', '1350 Hayes St', 'San Francisco', 'CA', '94117', '1600000', '3', '2.0', 'North Panhandle', '2317', '3436', '1888', '79', '691', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1350-Hayes-St-94117/home/596135', 'San Francisco MLS', '479740', 'N', 'Y', '37.7750997', '-122.438651']
# 1350 Hayes St
# San Francisco
# CA
# 94117
# North Panhandle
# 79
# 1600000
# February-5-2019
# 3.0
# 2.0
# 2317
# http://www.redfin.com/CA/San-Francisco/1350-Hayes-St-94117/home/596135
# 37.7750997
# -122.438651
# 1549353600
# ['PAST SALE', 'March-4-2019', 'Single Family Residential', '3050 Pierce St', 'San Francisco', 'CA', '94123', '1900000', '3', '2.0', 'Cow Hollow', '1445', '1118', '1900', '52', '1315', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/3050-Pierce-St-94123/home/562414', 'San Francisco MLS', '480648', 'N', 'Y', '37.7982753', '-122.4389495']
# 3050 Pierce St
# San Francisco
# CA
# 94123
# Cow Hollow
# 52
# 1900000
# March-4-2019
# 3.0
# 2.0
# 1445
# http://www.redfin.com/CA/San-Francisco/3050-Pierce-St-94123/home/562414
# 37.7982753
# -122.4389495
# 1551686400
# ['PAST SALE', 'April-22-2019', 'Single Family Residential', '341 Avila St', 'San Francisco', 'CA', '94123', '3000000', '5', '3.0', 'Marina', '3262', '3018', '1924', '3', '920', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/341-Avila-St-94123/home/1506887', 'San Francisco MLS', '479908', 'N', 'Y', '37.8044611', '-122.4413051']
# 341 Avila St
# San Francisco
# CA
# 94123
# Marina
# 3
# 3000000
# April-22-2019
# 5.0
# 3.0
# 3262
# http://www.redfin.com/CA/San-Francisco/341-Avila-St-94123/home/1506887
# 37.8044611
# -122.4413051
# 1555916400
# ['PAST SALE', 'February-1-2019', 'Single Family Residential', '1910 45th Ave', 'San Francisco', 'CA', '94116', '1250000', '4', '2.0', 'Outer Parkside', '1837', '1750', '1946', '83', '680', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1910-45th-Ave-94116/home/1164129', 'San Francisco MLS', '479600', 'N', 'Y', '37.7508827', '-122.503968']
# 1910 45th Ave
# San Francisco
# CA
# 94116
# Outer Parkside
# 83
# 1250000
# February-1-2019
# 4.0
# 2.0
# 1837
# http://www.redfin.com/CA/San-Francisco/1910-45th-Ave-94116/home/1164129
# 37.7508827
# -122.503968
# 1549008000
# ['PAST SALE', 'February-8-2019', 'Single Family Residential', '2211 44th Ave', 'SAN FRANCISCO', 'CA', '94116', '1752211', '4', '2.0', 'SAN FRANCISCO', '1867', '2622', '1928', '76', '939', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2211-44th-Ave-94116/home/655039', 'MLSListings', 'ML81733099', 'N', 'Y', '37.7453533', '-122.5029512']
# 2211 44th Ave
# SAN FRANCISCO
# CA
# 94116
# SAN FRANCISCO
# 76
# 1752211
# February-8-2019
# 4.0
# 2.0
# 1867
# http://www.redfin.com/CA/San-Francisco/2211-44th-Ave-94116/home/655039
# 37.7453533
# -122.5029512
# 1549612800
# ['PAST SALE', 'February-8-2019', 'Single Family Residential', '1446 38th Ave', 'San Francisco', 'CA', '94122', '1810000', '4', '3.5', 'Outer Sunset', '2396', '2750', '1935', '76', '755', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1446-38th-Ave-94122/home/1119341', 'San Francisco MLS', '479492', 'N', 'Y', '37.7599137', '-122.497038']
# 1446 38th Ave
# San Francisco
# CA
# 94122
# Outer Sunset
# 76
# 1810000
# February-8-2019
# 4.0
# 3.5
# 2396
# http://www.redfin.com/CA/San-Francisco/1446-38th-Ave-94122/home/1119341
# 37.7599137
# -122.497038
# 1549612800
# ['PAST SALE', 'February-9-2019', 'Single Family Residential', '3042 Noriega St', 'San Francisco', 'CA', '94122', '1625000', '4', '4.0', 'Outer Sunset', '2020', '2325', '1947', '75', '804', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/3042-Noriega-St-94122/home/963648', 'San Francisco MLS', '479765', 'N', 'Y', '37.7535454', '-122.4965406']
# 3042 Noriega St
# San Francisco
# CA
# 94122
# Outer Sunset
# 75
# 1625000
# February-9-2019
# 4.0
# 4.0
# 2020
# http://www.redfin.com/CA/San-Francisco/3042-Noriega-St-94122/home/963648
# 37.7535454
# -122.4965406
# 1549699200
# ['PAST SALE', 'February-28-2019', 'Single Family Residential', '1700 Great Hwy', 'San Francisco', 'CA', '94122', '1605000', '3', '2.0', 'Outer Sunset', '1393', '', '', '56', '1152', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1700-Great-Hwy-94122/home/1975468', 'San Francisco MLS', '480472', 'N', 'Y', '37.754558', '-122.508442']
# 1700 Great Hwy
# San Francisco
# CA
# 94122
# Outer Sunset
# 56
# 1605000
# February-28-2019
# 3.0
# 2.0
# 1393
# http://www.redfin.com/CA/San-Francisco/1700-Great-Hwy-94122/home/1975468
# 37.754558
# -122.508442
# 1551340800
# ['PAST SALE', 'March-27-2019', 'Single Family Residential', '2214 43rd Ave', 'San Francisco', 'CA', '94116', '1380000', '3', '2.0', 'Outer Parkside', '1402', '1750', '1947', '29', '984', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2214-43rd-Ave-94116/home/1428524', 'San Francisco MLS', '481525', 'N', 'Y', '37.7453095', '-122.5014038']
# 2214 43rd Ave
# San Francisco
# CA
# 94116
# Outer Parkside
# 29
# 1380000
# March-27-2019
# 3.0
# 2.0
# 1402
# http://www.redfin.com/CA/San-Francisco/2214-43rd-Ave-94116/home/1428524
# 37.7453095
# -122.5014038
# 1553670000
# ['PAST SALE', 'April-9-2019', 'Single Family Residential', '2924 Rivera St', 'SAN FRANCISCO', 'CA', '94116', '1400000', '3', '2.0', 'SAN FRANCISCO', '1409', '2500', '1947', '16', '994', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2924-Rivera-St-94116/home/652243', 'MLSListings', 'ML81741768', 'N', 'Y', '37.74606', '-122.497892']
# 2924 Rivera St
# SAN FRANCISCO
# CA
# 94116
# SAN FRANCISCO
# 16
# 1400000
# April-9-2019
# 3.0
# 2.0
# 1409
# http://www.redfin.com/CA/San-Francisco/2924-Rivera-St-94116/home/652243
# 37.74606
# -122.497892
# 1554793200
# ['PAST SALE', 'April-22-2019', 'Single Family Residential', '1200 48th Ave', 'San Francisco', 'CA', '94122', '1241000', '3', '2.0', 'Outer Sunset', '1250', '1438', '1943', '3', '993', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1200-48th-Ave-94122/home/1877870', 'San Francisco MLS', '482471', 'N', 'Y', '37.7639312', '-122.5081582']
# 1200 48th Ave
# San Francisco
# CA
# 94122
# Outer Sunset
# 3
# 1241000
# April-22-2019
# 3.0
# 2.0
# 1250
# http://www.redfin.com/CA/San-Francisco/1200-48th-Ave-94122/home/1877870
# 37.7639312
# -122.5081582
# 1555916400
# ['PAST SALE', 'March-27-2019', 'Single Family Residential', '3627 21st St', 'San Francisco', 'CA', '94114', '4500000', '3', '3.0', 'Eureka Valley/Dolore', '', '2850', '', '29', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/3627-21st-St-94114/home/715275', 'San Francisco MLS', '481791', 'N', 'Y', '37.7562054', '-122.4285989']
# 3627 21st St
# San Francisco
# CA
# 94114
# Eureka Valley/Dolore
# 29
# 4500000
# March-27-2019
# 3.0
# 3.0
# None
# http://www.redfin.com/CA/San-Francisco/3627-21st-St-94114/home/715275
# 37.7562054
# -122.4285989
# 1553670000
# ['PAST SALE', 'February-15-2019', 'Single Family Residential', '965 Natoma St', 'San Francisco', 'CA', '94103', '2148350', '3', '2.5', 'South of Market', '2924', '1875', '1906', '69', '735', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/965-Natoma-St-94103/home/1855207', 'San Francisco MLS', '481085', 'N', 'Y', '37.7737537', '-122.4155569']
# 965 Natoma St
# San Francisco
# CA
# 94103
# South of Market
# 69
# 2148350
# February-15-2019
# 3.0
# 2.5
# 2924
# http://www.redfin.com/CA/San-Francisco/965-Natoma-St-94103/home/1855207
# 37.7737537
# -122.4155569
# 1550217600
# ['PAST SALE', 'March-22-2019', 'Single Family Residential', '', 'San Francisco', 'CA', '94118', '5950000', '5', '3.5', 'Lake', '', '', '', '34', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/Undisclosed-address-94118/home/1237205', 'San Francisco MLS', '480366', 'N', 'Y', '37.7885455', '-122.463509']
#
# San Francisco
# CA
# 94118
# Lake
# 34
# 5950000
# March-22-2019
# 5.0
# 3.5
# None
# http://www.redfin.com/CA/San-Francisco/Undisclosed-address-94118/home/1237205
# 37.7885455
# -122.463509
# 1553238000
# ['PAST SALE', 'April-8-2019', 'Single Family Residential', '65 Stanyan St', 'San Francisco', 'CA', '94118', '2175000', '4', '2.5', 'Lone Mountain', '2415', '2670', '1937', '17', '901', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/65-Stanyan-St-94118/home/1199543', 'San Francisco MLS', '481417', 'N', 'Y', '37.780379', '-122.456408']
# 65 Stanyan St
# San Francisco
# CA
# 94118
# Lone Mountain
# 17
# 2175000
# April-8-2019
# 4.0
# 2.5
# 2415
# http://www.redfin.com/CA/San-Francisco/65-Stanyan-St-94118/home/1199543
# 37.780379
# -122.456408
# 1554706800
# ['PAST SALE', 'April-9-2019', 'Single Family Residential', '31-33 Beaumont Ave', 'San Francisco', 'CA', '94118', '2350000', '3', '2.5', 'Lone Mountain', '3375', '2500', '1996', '16', '696', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/31-Beaumont-Ave-94118/home/2033312', 'San Francisco MLS', '477472', 'N', 'Y', '37.7808704', '-122.4554624']
# 31-33 Beaumont Ave
# San Francisco
# CA
# 94118
# Lone Mountain
# 16
# 2350000
# April-9-2019
# 3.0
# 2.5
# 3375
# http://www.redfin.com/CA/San-Francisco/31-Beaumont-Ave-94118/home/2033312
# 37.7808704
# -122.4554624
# 1554793200
# ['PAST SALE', 'January-28-2019', 'Single Family Residential', '1116 Greenwich St', 'San Francisco', 'CA', '94109', '2650000', '3', '3.0', 'Russian Hill', '', '2866', '1941', '87', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1116-Greenwich-St-94109/home/539654', 'San Francisco MLS', '471015', 'N', 'Y', '37.8014467', '-122.4182117']
# 1116 Greenwich St
# San Francisco
# CA
# 94109
# Russian Hill
# 87
# 2650000
# January-28-2019
# 3.0
# 3.0
# None
# http://www.redfin.com/CA/San-Francisco/1116-Greenwich-St-94109/home/539654
# 37.8014467
# -122.4182117
# 1548662400
# ['PAST SALE', 'February-13-2019', 'Single Family Residential', '584 Dewey Blvd', 'San Francisco', 'CA', '94116', '2400000', '5', '6.5', 'Forest Hill', '3664', '3833', '1923', '71', '655', '37', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/584-Dewey-Blvd-94116/home/1526004', 'San Francisco MLS', '480428', 'N', 'Y', '37.7442062', '-122.4635532']
# 584 Dewey Blvd
# San Francisco
# CA
# 94116
# Forest Hill
# 71
# 2400000
# February-13-2019
# 5.0
# 6.5
# 3664
# http://www.redfin.com/CA/San-Francisco/584-Dewey-Blvd-94116/home/1526004
# 37.7442062
# -122.4635532
# 1550044800
# ['PAST SALE', 'March-22-2019', 'Single Family Residential', '263 Arch St', 'San Francisco', 'CA', '94132', '1200000', '3', '2.0', 'Ingleside Heights', '1465', '2495', '1940', '34', '819', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/263-Arch-St-94132/home/827793', 'San Francisco MLS', '480215', 'N', 'Y', '37.7154572', '-122.4673123']
# 263 Arch St
# San Francisco
# CA
# 94132
# Ingleside Heights
# 34
# 1200000
# March-22-2019
# 3.0
# 2.0
# 1465
# http://www.redfin.com/CA/San-Francisco/263-Arch-St-94132/home/827793
# 37.7154572
# -122.4673123
# 1553238000
# ['PAST SALE', 'April-17-2019', 'Single Family Residential', '66 Granada', 'San Francisco', 'CA', '94112', '1160000', '3', '2.0', 'Ingleside', '1100', '2813', '1922', '8', '1055', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/66-Granada-Ave-94112/home/996902', 'San Francisco MLS', '481897', 'N', 'Y', '37.719433', '-122.456908']
# 66 Granada
# San Francisco
# CA
# 94112
# Ingleside
# 8
# 1160000
# April-17-2019
# 3.0
# 2.0
# 1100
# http://www.redfin.com/CA/San-Francisco/66-Granada-Ave-94112/home/996902
# 37.719433
# -122.456908
# 1555484400
# ['PAST SALE', 'April-10-2019', 'Single Family Residential', '860 De Haro St', 'SAN FRANCISCO', 'CA', '94107', '3150000', '3', '4.0', 'SAN FRANCISCO', '2323', '2500', '1984', '15', '1356', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/860-De-Haro-St-94107/home/1121615', 'MLSListings', 'ML81728277', 'N', 'Y', '37.7588646', '-122.4013418']
# 860 De Haro St
# SAN FRANCISCO
# CA
# 94107
# SAN FRANCISCO
# 15
# 3150000
# April-10-2019
# 3.0
# 4.0
# 2323
# http://www.redfin.com/CA/San-Francisco/860-De-Haro-St-94107/home/1121615
# 37.7588646
# -122.4013418
# 1554879600
# ['PAST SALE', 'February-15-2019', 'Single Family Residential', '647 Teresita Blvd', 'San Francisco', 'CA', '94127', '1385000', '4', '2.0', 'Miraloma Park', '2337', '3920', '1961', '69', '593', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/647-Teresita-Blvd-94127/home/1421704', 'San Francisco MLS', '475557', 'N', 'Y', '37.7365671', '-122.4455516']
# 647 Teresita Blvd
# San Francisco
# CA
# 94127
# Miraloma Park
# 69
# 1385000
# February-15-2019
# 4.0
# 2.0
# 2337
# http://www.redfin.com/CA/San-Francisco/647-Teresita-Blvd-94127/home/1421704
# 37.7365671
# -122.4455516
# 1550217600
# ['PAST SALE', 'February-22-2019', 'Single Family Residential', '397 Mangels Ave', 'San Francisco', 'CA', '94127', '1375000', '5', '2.0', 'San Francisco County', '1678', '', '1961', '62', '819', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/397-Mangels-Ave-94127/home/691128', 'BAREIS', '21900878', 'N', 'Y', '37.7329771', '-122.446569']
# 397 Mangels Ave
# San Francisco
# CA
# 94127
# San Francisco County
# 62
# 1375000
# February-22-2019
# 5.0
# 2.0
# 1678
# http://www.redfin.com/CA/San-Francisco/397-Mangels-Ave-94127/home/691128
# 37.7329771
# -122.446569
# 1550822400
# ['PAST SALE', 'February-25-2019', 'Single Family Residential', '143 Detroit St', 'San Francisco', 'CA', '94131', '1450000', '3', '2.0', 'Sunnyside', '1400', '1873', '1925', '59', '1036', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/143-Detroit-St-94131/home/697726', 'San Francisco MLS', '480420', 'N', 'Y', '37.728892', '-122.444518']
# 143 Detroit St
# San Francisco
# CA
# 94131
# Sunnyside
# 59
# 1450000
# February-25-2019
# 3.0
# 2.0
# 1400
# http://www.redfin.com/CA/San-Francisco/143-Detroit-St-94131/home/697726
# 37.728892
# -122.444518
# 1551081600
# ['PAST SALE', 'February-28-2019', 'Single Family Residential', '136 Marietta Dr', 'San Francisco', 'CA', '94127', '1520000', '3', '2.0', 'Miraloma Park', '1326', '2644', '1943', '56', '1146', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/136-Marietta-Dr-94127/home/983044', 'San Francisco MLS', '480066', 'N', 'Y', '37.740571', '-122.448051']
# 136 Marietta Dr
# San Francisco
# CA
# 94127
# Miraloma Park
# 56
# 1520000
# February-28-2019
# 3.0
# 2.0
# 1326
# http://www.redfin.com/CA/San-Francisco/136-Marietta-Dr-94127/home/983044
# 37.740571
# -122.448051
# 1551340800
# ['PAST SALE', 'February-21-2019', 'Single Family Residential', '240 Upland Dr', 'San Francisco', 'CA', '94127', '2200000', '4', '3.0', 'Mount Davidson Manor', '2782', '3341', '1930', '63', '791', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/240-Upland-Dr-94127/home/1820405', 'San Francisco MLS', '479902', 'N', 'Y', '37.729712', '-122.4639512']
# 240 Upland Dr
# San Francisco
# CA
# 94127
# Mount Davidson Manor
# 63
# 2200000
# February-21-2019
# 4.0
# 3.0
# 2782
# http://www.redfin.com/CA/San-Francisco/240-Upland-Dr-94127/home/1820405
# 37.729712
# -122.4639512
# 1550736000
# ['PAST SALE', 'March-1-2019', 'Single Family Residential', '68 Burlwood Dr', 'San Francisco', 'CA', '94127', '1650000', '3', '3.5', 'Westwood Highlands', '2259', '5471', '1947', '55', '730', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/68-Burlwood-Dr-94127/home/1361218', 'San Francisco MLS', '480488', 'N', 'Y', '37.7346073', '-122.4537345']
# 68 Burlwood Dr
# San Francisco
# CA
# 94127
# Westwood Highlands
# 55
# 1650000
# March-1-2019
# 3.0
# 3.5
# 2259
# http://www.redfin.com/CA/San-Francisco/68-Burlwood-Dr-94127/home/1361218
# 37.7346073
# -122.4537345
# 1551427200
# ['PAST SALE', 'March-13-2019', 'Single Family Residential', '240 Juanita Way', 'San Francisco', 'CA', '94127', '1708000', '3', '2.0', 'Miraloma Park', '2450', '', '1927', '43', '697', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/240-Juanita-Way-94127/home/685683', 'San Francisco MLS', '476368', 'N', 'Y', '37.7407696', '-122.4566979']
# 240 Juanita Way
# San Francisco
# CA
# 94127
# Miraloma Park
# 43
# 1708000
# March-13-2019
# 3.0
# 2.0
# 2450
# http://www.redfin.com/CA/San-Francisco/240-Juanita-Way-94127/home/685683
# 37.7407696
# -122.4566979
# 1552460400
# ['PAST SALE', 'March-15-2019', 'Single Family Residential', '80 Stanford Heights Ave', 'San Francisco', 'CA', '94127', '1605000', '3', '2.5', 'Miraloma Park', '1921', '3084', '1964', '41', '836', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/80-Stanford-Heights-Ave-94127/home/690277', 'San Francisco MLS', '481209', 'N', 'Y', '37.7353857', '-122.4497537']
# 80 Stanford Heights Ave
# San Francisco
# CA
# 94127
# Miraloma Park
# 41
# 1605000
# March-15-2019
# 3.0
# 2.5
# 1921
# http://www.redfin.com/CA/San-Francisco/80-Stanford-Heights-Ave-94127/home/690277
# 37.7353857
# -122.4497537
# 1552633200
# ['PAST SALE', 'March-29-2019', 'Single Family Residential', '118 Santa Clara Ave', 'San Francisco', 'CA', '94127', '2950000', '4', '4.5', 'St. Francis Wood', '3602', '4987', '1922', '27', '819', '184', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/118-Santa-Clara-Ave-94127/home/1900606', 'San Francisco MLS', '480745', 'N', 'Y', '37.7371989', '-122.4661183']
# 118 Santa Clara Ave
# San Francisco
# CA
# 94127
# St. Francis Wood
# 27
# 2950000
# March-29-2019
# 4.0
# 4.5
# 3602
# http://www.redfin.com/CA/San-Francisco/118-Santa-Clara-Ave-94127/home/1900606
# 37.7371989
# -122.4661183
# 1553842800
# ['PAST SALE', 'March-29-2019', 'Single Family Residential', '9 Burlwood Dr', 'San Francisco', 'CA', '94127', '2280000', '4', '3.0', 'Westwood Highlands', '2377', '4085', '1979', '27', '959', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/9-Burlwood-Dr-94127/home/687794', 'San Francisco MLS', '481548', 'N', 'Y', '37.7350008', '-122.4552384']
# 9 Burlwood Dr
# San Francisco
# CA
# 94127
# Westwood Highlands
# 27
# 2280000
# March-29-2019
# 4.0
# 3.0
# 2377
# http://www.redfin.com/CA/San-Francisco/9-Burlwood-Dr-94127/home/687794
# 37.7350008
# -122.4552384
# 1553842800
# ['PAST SALE', 'April-8-2019', 'Single Family Residential', '31 Rosewood Dr', 'San Francisco', 'CA', '94127', '3120000', '5', '4.0', 'Monterey Heights', '3407', '4011', '1927', '17', '916', '2', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/31-Rosewood-Dr-94127/home/1750688', 'San Francisco MLS', '480571', 'N', 'Y', '37.7343759', '-122.4604131']
# 31 Rosewood Dr
# San Francisco
# CA
# 94127
# Monterey Heights
# 17
# 3120000
# April-8-2019
# 5.0
# 4.0
# 3407
# http://www.redfin.com/CA/San-Francisco/31-Rosewood-Dr-94127/home/1750688
# 37.7343759
# -122.4604131
# 1554706800
# ['PAST SALE', 'April-12-2019', 'Single Family Residential', '113 Knockash Hl', 'San Francisco', 'CA', '94127', '2440000', '5', '4.5', 'Forest Hill Extension', '3569', '2624', '1995', '13', '684', '290', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/113-Knockash-Hl-94127/home/681834', 'San Francisco MLS', '482899', 'N', 'Y', '37.741980436', '-122.4584197']
# 113 Knockash Hl
# San Francisco
# CA
# 94127
# Forest Hill Extension
# 13
# 2440000
# April-12-2019
# 5.0
# 4.5
# 3569
# http://www.redfin.com/CA/San-Francisco/113-Knockash-Hl-94127/home/681834
# 37.741980436
# -122.4584197
# 1555052400
# ['PAST SALE', 'April-12-2019', 'Single Family Residential', '145 Manor Dr', 'San Francisco', 'CA', '94127', '1450000', '3', '2.0', 'Mount Davidson Manor', '1612', '2827', '1928', '13', '900', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/145-Manor-Dr-94127/home/2027456', 'San Francisco MLS', '481542', 'N', 'Y', '37.7287947', '-122.463907']
# 145 Manor Dr
# San Francisco
# CA
# 94127
# Mount Davidson Manor
# 13
# 1450000
# April-12-2019
# 3.0
# 2.0
# 1612
# http://www.redfin.com/CA/San-Francisco/145-Manor-Dr-94127/home/2027456
# 37.7287947
# -122.463907
# 1555052400
# ['PAST SALE', 'April-1-2019', 'Single Family Residential', '444 29th St', 'San Francisco', 'CA', '94131', '1785000', '3', '2.0', 'Noe Valley', '1571', '2848', '1571', '24', '1136', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/444-29th-St-94131/home/898482', 'San Francisco MLS', '480496', 'N', 'Y', '37.743665', '-122.4300134']
# 444 29th St
# San Francisco
# CA
# 94131
# Noe Valley
# 24
# 1785000
# April-1-2019
# 3.0
# 2.0
# 1571
# http://www.redfin.com/CA/San-Francisco/444-29th-St-94131/home/898482
# 37.743665
# -122.4300134
# 1554102000
# ['PAST SALE', 'April-15-2019', 'Single Family Residential', '455 28th St', 'San Francisco', 'CA', '94131', '1652000', '3', '2.0', 'Noe Valley', '1682', '2848', '1941', '10', '982', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/455-28th-St-94131/home/806595', 'San Francisco MLS', '481536', 'N', 'Y', '37.7447894', '-122.4325019']
# 455 28th St
# San Francisco
# CA
# 94131
# Noe Valley
# 10
# 1652000
# April-15-2019
# 3.0
# 2.0
# 1682
# http://www.redfin.com/CA/San-Francisco/455-28th-St-94131/home/806595
# 37.7447894
# -122.4325019
# 1555311600
# ['PAST SALE', 'February-1-2019', 'Single Family Residential', '766 Vienna St', 'San Francisco', 'CA', '94112', '1205000', '4', '2.0', 'Excelsior', '', '2500', '1926', '83', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/766-Vienna-St-94112/home/1829255', 'San Francisco MLS', '479340', 'N', 'Y', '37.7164209', '-122.4337074']
# 766 Vienna St
# San Francisco
# CA
# 94112
# Excelsior
# 83
# 1205000
# February-1-2019
# 4.0
# 2.0
# None
# http://www.redfin.com/CA/San-Francisco/766-Vienna-St-94112/home/1829255
# 37.7164209
# -122.4337074
# 1549008000
# ['PAST SALE', 'April-2-2019', 'Single Family Residential', '2832 Sacramento', 'San Francisco', 'CA', '94115', '5500000', '4', '3.5', 'Pacific Heights', '3200', '3100', '1885', '23', '1719', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2832-Sacramento-St-94115/home/1475944', 'San Francisco MLS', '482392', 'N', 'Y', '37.789391', '-122.439619']
# 2832 Sacramento
# San Francisco
# CA
# 94115
# Pacific Heights
# 23
# 5500000
# April-2-2019
# 4.0
# 3.5
# 3200
# http://www.redfin.com/CA/San-Francisco/2832-Sacramento-St-94115/home/1475944
# 37.789391
# -122.439619
# 1554188400
# ...
# 10 Perine Pl
# San Francisco
# CA
# 94115
# Pacific Heights
# 84
# 2750000
# January-31-2019
# 4.0
# 2.0
# None
# http://www.redfin.com/CA/San-Francisco/10-Perine-Pl-94115/home/1642479
# 37.7892069
# -122.4360241
# 1548921600
# ['PAST SALE', 'April-19-2019', 'Single Family Residential', '112 Mallorca Way', 'San Francisco', 'CA', '94123', '4845000', '5', '4.5', 'San Francisco County', '4810', '', '1924', '6', '1007', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/112-Mallorca-Way-94123/home/1845917', 'BAREIS', '21901022', 'N', 'Y', '37.801871', '-122.437277']
# 112 Mallorca Way
# San Francisco
# CA
# 94123
# San Francisco County
# 6
# 4845000
# April-19-2019
# 5.0
# 4.5
# 4810
# http://www.redfin.com/CA/San-Francisco/112-Mallorca-Way-94123/home/1845917
# 37.801871
# -122.437277
# 1555657200
# ['PAST SALE', 'April-23-2019', 'Single Family Residential', '278 Mallorca Way', 'San Francisco', 'CA', '94123', '2750000', '3', '2.5', 'Marina', '2175', '', '1925', '2', '1264', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/278-Mallorca-Way-94123/home/1825016', 'San Francisco MLS', '480398', 'N', 'Y', '37.8035658', '-122.4391376']
# 278 Mallorca Way
# San Francisco
# CA
# 94123
# Marina
# 2
# 2750000
# April-23-2019
# 3.0
# 2.5
# 2175
# http://www.redfin.com/CA/San-Francisco/278-Mallorca-Way-94123/home/1825016
# 37.8035658
# -122.4391376
# 1556002800
# ['PAST SALE', 'April-24-2019', 'Single Family Residential', '2714 Pacific Ave', 'San Francisco', 'CA', '94115', '11900000', '4', '5.0', 'Pacific Heights', '4930', '3654', '1914', '1', '2414', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2714-Pacific-Ave-94115/home/1340861', 'San Francisco MLS', '483116', 'N', 'Y', '37.7927555', '-122.440359']
# 2714 Pacific Ave
# San Francisco
# CA
# 94115
# Pacific Heights
# 1
# 11900000
# April-24-2019
# 4.0
# 5.0
# 4930
# http://www.redfin.com/CA/San-Francisco/2714-Pacific-Ave-94115/home/1340861
# 37.7927555
# -122.440359
# 1556089200
# ['PAST SALE', 'March-12-2019', 'Single Family Residential', '2271 40th Ave', 'SAN FRANCISCO', 'CA', '94116', '1768500', '4', '4.0', 'SAN FRANCISCO', '1775', '2996', '1948', '44', '996', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2271-40th-Ave-94116/home/1092387', 'MLSListings', 'ML81734796', 'N', 'Y', '37.74447', '-122.4985744']
# 2271 40th Ave
# SAN FRANCISCO
# CA
# 94116
# SAN FRANCISCO
# 44
# 1768500
# March-12-2019
# 4.0
# 4.0
# 1775
# http://www.redfin.com/CA/San-Francisco/2271-40th-Ave-94116/home/1092387
# 37.74447
# -122.4985744
# 1552374000
# ['PAST SALE', 'March-27-2019', 'Single Family Residential', '2007 47th Ave', 'San Francisco', 'CA', '94116', '1600000', '3', '2.0', 'Outer Parkside', '1651', '2060', '1946', '29', '969', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2007-47th-Ave-94116/home/1900045', 'San Francisco MLS', '481743', 'N', 'Y', '37.7489654', '-122.5064437']
# 2007 47th Ave
# San Francisco
# CA
# 94116
# Outer Parkside
# 29
# 1600000
# March-27-2019
# 3.0
# 2.0
# 1651
# http://www.redfin.com/CA/San-Francisco/2007-47th-Ave-94116/home/1900045
# 37.7489654
# -122.5064437
# 1553670000
# ['PAST SALE', 'April-24-2019', 'Single Family Residential', '2275 45th Ave', 'San Francisco', 'CA', '94116', '1800000', '3', '2.5', 'Outer Parkside', '2260', '2996', '1931', '1', '796', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/2275-45th-Ave-94116/home/654687', 'San Francisco MLS', '481845', 'N', 'Y', '37.7441617', '-122.5039595']
# 2275 45th Ave
# San Francisco
# CA
# 94116
# Outer Parkside
# 1
# 1800000
# April-24-2019
# 3.0
# 2.5
# 2260
# http://www.redfin.com/CA/San-Francisco/2275-45th-Ave-94116/home/654687
# 37.7441617
# -122.5039595
# 1556089200
# ['PAST SALE', 'January-30-2019', 'Single Family Residential', '368 Bradford St', 'San Francisco', 'CA', '94110', '1300000', '4', '3.0', 'Bernal Heights', '1620', '2099', '1962', '85', '802', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/368-Bradford-St-94110/home/1264728', 'San Francisco MLS', '478360', 'N', 'Y', '37.7372159', '-122.4098932']
# 368 Bradford St
# San Francisco
# CA
# 94110
# Bernal Heights
# 85
# 1300000
# January-30-2019
# 4.0
# 3.0
# 1620
# http://www.redfin.com/CA/San-Francisco/368-Bradford-St-94110/home/1264728
# 37.7372159
# -122.4098932
# 1548835200
# ['PAST SALE', 'April-5-2019', 'Single Family Residential', '27 Putnam', 'San Francisco', 'CA', '94110', '1425000', '3', '2.0', 'Bernal Heights', '', '', '', '20', '', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/27-Putnam-St-94110/home/1727401', 'San Francisco MLS', '480577', 'N', 'Y', '37.7393812', '-122.4106344']
# 27 Putnam
# San Francisco
# CA
# 94110
# Bernal Heights
# 20
# 1425000
# April-5-2019
# 3.0
# 2.0
# None
# http://www.redfin.com/CA/San-Francisco/27-Putnam-St-94110/home/1727401
# 37.7393812
# -122.4106344
# 1554447600
# ['PAST SALE', 'April-18-2019', 'Single Family Residential', '398 Harkness Ave', 'San Francisco', 'CA', '94134', '1110000', '3', '2.0', 'Visitacion Valley', '1305', '1873', '1960', '7', '851', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/398-Harkness-Ave-94134/home/782252', 'San Francisco MLS', '480478', 'N', 'Y', '37.7181313', '-122.4052028']
# 398 Harkness Ave
# San Francisco
# CA
# 94134
# Visitacion Valley
# 7
# 1110000
# April-18-2019
# 3.0
# 2.0
# 1305
# http://www.redfin.com/CA/San-Francisco/398-Harkness-Ave-94134/home/782252
# 37.7181313
# -122.4052028
# 1555570800
# ['PAST SALE', 'April-12-2019', 'Single Family Residential', '809 Noriega St', 'San Francisco', 'CA', '94122', '1750000', '4', '4.0', 'Golden Gate Heig', '2541', '3924', '1946', '13', '689', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/809-Noriega-St-94122/home/1556554', 'Bridge MLS', '40857155', 'N', 'Y', '37.7544461', '-122.4724865']
# 809 Noriega St
# San Francisco
# CA
# 94122
# Golden Gate Heig
# 13
# 1750000
# April-12-2019
# 4.0
# 4.0
# 2541
# http://www.redfin.com/CA/San-Francisco/809-Noriega-St-94122/home/1556554
# 37.7544461
# -122.4724865
# 1555052400
# ['PAST SALE', 'February-28-2019', 'Single Family Residential', '160 Miraloma Dr', 'San Francisco', 'CA', '94127', '3650000', '5', '4.5', 'Monterey Heights', '5274', '9997', '1926', '56', '692', '2', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/160-Miraloma-Dr-94127/home/1369538', 'San Francisco MLS', '480720', 'N', 'Y', '37.7365846', '-122.4613419']
# 160 Miraloma Dr
# San Francisco
# CA
# 94127
# Monterey Heights
# 56
# 3650000
# February-28-2019
# 5.0
# 4.5
# 5274
# http://www.redfin.com/CA/San-Francisco/160-Miraloma-Dr-94127/home/1369538
# 37.7365846
# -122.4613419
# 1551340800
# ['PAST SALE', 'March-18-2019', 'Single Family Residential', '225 Edgehill Way', 'San Francisco', 'CA', '94127', '2185000', '3', '2.5', 'Forest Hill Extension', '2346', '3985', '1948', '38', '931', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/225-Edgehill-Way-94127/home/681994', 'San Francisco MLS', '481122', 'N', 'Y', '37.7433796', '-122.4588319']
# 225 Edgehill Way
# San Francisco
# CA
# 94127
# Forest Hill Extension
# 38
# 2185000
# March-18-2019
# 3.0
# 2.5
# 2346
# http://www.redfin.com/CA/San-Francisco/225-Edgehill-Way-94127/home/681994
# 37.7433796
# -122.4588319
# 1552892400
# ['PAST SALE', 'March-29-2019', 'Single Family Residential', '130 Yerba Buena Ave', 'San Francisco', 'CA', '94127', '2220000', '3', '3.0', 'St. Francis Wood', '2546', '3519', '1925', '27', '872', '129', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/130-Yerba-Buena-Ave-94127/home/2004611', 'San Francisco MLS', '481124', 'N', 'Y', '37.7364776', '-122.462536']
# 130 Yerba Buena Ave
# San Francisco
# CA
# 94127
# St. Francis Wood
# 27
# 2220000
# March-29-2019
# 3.0
# 3.0
# 2546
# http://www.redfin.com/CA/San-Francisco/130-Yerba-Buena-Ave-94127/home/2004611
# 37.7364776
# -122.462536
# 1553842800
# ['PAST SALE', 'April-4-2019', 'Single Family Residential', '525 Holloway Ave', 'SAN FRANCISCO', 'CA', '94112', '1450000', '5', '5.0', 'SAN FRANCISCO', '2296', '2500', '1923', '21', '632', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/525-Holloway-Ave-94112/home/996826', 'MLSListings', 'ML81731900', 'N', 'Y', '37.7216561', '-122.4586993']
# 525 Holloway Ave
# SAN FRANCISCO
# CA
# 94112
# SAN FRANCISCO
# 21
# 1450000
# April-4-2019
# 5.0
# 5.0
# 2296
# http://www.redfin.com/CA/San-Francisco/525-Holloway-Ave-94112/home/996826
# 37.7216561
# -122.4586993
# 1554361200
# ['PAST SALE', 'April-9-2019', 'Single Family Residential', '209 Crestmont Dr', 'San Francisco', 'CA', '94131', '1725000', '3', '2.0', 'Forest Knolls', '1404', '2629', '1963', '16', '1229', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/209-Crestmont-Dr-94131/home/2021755', 'San Francisco MLS', '481932', 'N', 'Y', '37.7562202', '-122.4598381']
# 209 Crestmont Dr
# San Francisco
# CA
# 94131
# Forest Knolls
# 16
# 1725000
# April-9-2019
# 3.0
# 2.0
# 1404
# http://www.redfin.com/CA/San-Francisco/209-Crestmont-Dr-94131/home/2021755
# 37.7562202
# -122.4598381
# 1554793200
# ['PAST SALE', 'April-10-2019', 'Single Family Residential', '534 Dewey Blvd', 'San Francisco', 'CA', '94116', '1750000', '4', '2.0', 'Forest Hill', '2150', '4399', '1924', '15', '814', '38', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/534-Dewey-Blvd-94116/home/2013565', 'San Francisco MLS', '482856', 'N', 'Y', '37.7449934', '-122.4624475']
# 534 Dewey Blvd
# San Francisco
# CA
# 94116
# Forest Hill
# 15
# 1750000
# April-10-2019
# 4.0
# 2.0
# 2150
# http://www.redfin.com/CA/San-Francisco/534-Dewey-Blvd-94116/home/2013565
# 37.7449934
# -122.4624475
# 1554879600
# ['PAST SALE', 'April-8-2019', 'Single Family Residential', '250 Maywood Dr', 'San Francisco', 'CA', '94127', '2755000', '4', '3.0', 'Monterey Heights', '3035', '4146', '1937', '17', '908', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/250-Maywood-Dr-94127/home/1645460', 'San Francisco MLS', '482030', 'N', 'Y', '37.732261', '-122.461961']
# 250 Maywood Dr
# San Francisco
# CA
# 94127
# Monterey Heights
# 17
# 2755000
# April-8-2019
# 4.0
# 3.0
# 3035
# http://www.redfin.com/CA/San-Francisco/250-Maywood-Dr-94127/home/1645460
# 37.732261
# -122.461961
# 1554706800
# ['PAST SALE', 'April-19-2019', 'Single Family Residential', '60 Santa Rita Ave', 'San Francisco', 'CA', '94116', '2415000', '3', '2.5', 'Forest Hill', '2156', '3593', '1940', '6', '1120', '63', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/60-Santa-Rita-Ave-94116/home/1590298', 'San Francisco MLS', '482025', 'N', 'Y', '37.7475435', '-122.4647141']
# 60 Santa Rita Ave
# San Francisco
# CA
# 94116
# Forest Hill
# 6
# 2415000
# April-19-2019
# 3.0
# 2.5
# 2156
# http://www.redfin.com/CA/San-Francisco/60-Santa-Rita-Ave-94116/home/1590298
# 37.7475435
# -122.4647141
# 1555657200
# ['PAST SALE', 'February-25-2019', 'Single Family Residential', '1068 Gilman Ave', 'San Francisco', 'CA', '94124', '1096000', '6', '3.0', 'Bayview', '2132', '4100', '1908', '59', '514', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1068-Gilman-Ave-94124/home/744295', 'San Francisco MLS', '478851', 'N', 'Y', '37.7191604', '-122.3893051']
# 1068 Gilman Ave
# San Francisco
# CA
# 94124
# Bayview
# 59
# 1096000
# February-25-2019
# 6.0
# 3.0
# 2132
# http://www.redfin.com/CA/San-Francisco/1068-Gilman-Ave-94124/home/744295
# 37.7191604
# -122.3893051
# 1551081600
# ['PAST SALE', 'March-7-2019', 'Single Family Residential', '3961 26th St', 'San Francisco', 'CA', '94131', '2350000', '4', '3.0', 'Noe Valley', '2113', '3112', '1908', '49', '1112', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/3961-26th-St-94131/home/2019939', 'San Francisco MLS', '480960', 'N', 'Y', '37.7481719', '-122.428488']
# 3961 26th St
# San Francisco
# CA
# 94131
# Noe Valley
# 49
# 2350000
# March-7-2019
# 4.0
# 3.0
# 2113
# http://www.redfin.com/CA/San-Francisco/3961-26th-St-94131/home/2019939
# 37.7481719
# -122.428488
# 1551945600
# ['PAST SALE', 'March-22-2019', 'Single Family Residential', '53 Florentine St', 'San Francisco', 'CA', '94112', '1140000', '4', '2.0', 'Crocker Amazon', '1471', '2247', '1924', '34', '775', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/53-Florentine-St-94112/home/795313', 'San Francisco MLS', '481639', 'N', 'Y', '37.7126159', '-122.4433842']
# 53 Florentine St
# San Francisco
# CA
# 94112
# Crocker Amazon
# 34
# 1140000
# March-22-2019
# 4.0
# 2.0
# 1471
# http://www.redfin.com/CA/San-Francisco/53-Florentine-St-94112/home/795313
# 37.7126159
# -122.4433842
# 1553238000
# ['PAST SALE', 'April-11-2019', 'Single Family Residential', '34 Wanda St', 'SAN FRANCISCO', 'CA', '94112', '1100000', '3', '2.0', 'SAN FRANCISCO', '1495', '2147', '1913', '14', '736', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/34-Wanda-St-94112/home/1440540', 'MLSListings', 'ML81732974', 'N', 'Y', '37.7230402', '-122.440343']
# 34 Wanda St
# SAN FRANCISCO
# CA
# 94112
# SAN FRANCISCO
# 14
# 1100000
# April-11-2019
# 3.0
# 2.0
# 1495
# http://www.redfin.com/CA/San-Francisco/34-Wanda-St-94112/home/1440540
# 37.7230402
# -122.440343
# 1554966000
# ['PAST SALE', 'March-12-2019', 'Single Family Residential', '479 Hoffman Ave', 'San Francisco', 'CA', '94114', '2400000', '3', '2.0', 'Noe Valley', '1964', '3123', '1931', '44', '1222', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/479-Hoffman-Ave-94114/home/888393', 'San Francisco MLS', '480234', 'N', 'Y', '37.7496941', '-122.4402958']
# 479 Hoffman Ave
# San Francisco
# CA
# 94114
# Noe Valley
# 44
# 2400000
# March-12-2019
# 3.0
# 2.0
# 1964
# http://www.redfin.com/CA/San-Francisco/479-Hoffman-Ave-94114/home/888393
# 37.7496941
# -122.4402958
# 1552374000
# ['PAST SALE', 'February-28-2019', 'Single Family Residential', '672 28th St', 'San Francisco', 'CA', '94131', '3000000', '4', '2.5', 'Noe Valley', '2747', '2848', '1910', '56', '1092', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/672-28th-St-94131/home/1584246', 'San Francisco MLS', '480341', 'N', 'Y', '37.744912', '-122.437293']
# 672 28th St
# San Francisco
# CA
# 94131
# Noe Valley
# 56
# 3000000
# February-28-2019
# 4.0
# 2.5
# 2747
# http://www.redfin.com/CA/San-Francisco/672-28th-St-94131/home/1584246
# 37.744912
# -122.437293
# 1551340800
# ['PAST SALE', 'March-5-2019', 'Single Family Residential', '221 San Juan Ave', 'San Francisco', 'CA', '94112', '1300000', '3', '2.0', 'Mission Terrace', '1270', '2670', '1936', '51', '1024', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/221-San-Juan-Ave-94112/home/2036999', 'San Francisco MLS', '480858', 'N', 'Y', '37.725067', '-122.4383855']
# 221 San Juan Ave
# San Francisco
# CA
# 94112
# Mission Terrace
# 51
# 1300000
# March-5-2019
# 3.0
# 2.0
# 1270
# http://www.redfin.com/CA/San-Francisco/221-San-Juan-Ave-94112/home/2036999
# 37.725067
# -122.4383855
# 1551772800
# ['PAST SALE', 'February-19-2019', 'Single Family Residential', '250 Gates St', 'San Francisco', 'CA', '94110', '1800250', '3', '2.0', 'Bernal Heights', '1384', '1750', '', '65', '1301', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/250-Gates-St-94110/home/1064985', 'San Francisco MLS', '480299', 'N', 'Y', '37.739635', '-122.414141']
# 250 Gates St
# San Francisco
# CA
# 94110
# Bernal Heights
# 65
# 1800250
# February-19-2019
# 3.0
# 2.0
# 1384
# http://www.redfin.com/CA/San-Francisco/250-Gates-St-94110/home/1064985
# 37.739635
# -122.414141
# 1550563200
# ['PAST SALE', 'February-4-2019', 'Single Family Residential', '1043 Jamestown Ave', 'San Francisco', 'CA', '94124', '945000', '3', '2.0', 'San Francisco County', '1360', '2500', '1967', '80', '695', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/1043-Jamestown-Ave-94124/home/1166841', 'BAREIS', '21820449', 'N', 'Y', '37.7188281', '-122.3945931']
# 1043 Jamestown Ave
# San Francisco
# CA
# 94124
# San Francisco County
# 80
# 945000
# February-4-2019
# 3.0
# 2.0
# 1360
# http://www.redfin.com/CA/San-Francisco/1043-Jamestown-Ave-94124/home/1166841
# 37.7188281
# -122.3945931
# 1549267200
# ['PAST SALE', 'April-9-2019', 'Single Family Residential', '554 Anderson St', 'San Francisco', 'CA', '94110', '1830000', '5', '4.0', 'Bernal Heights', '1900', '', '', '16', '963', '', 'Sold', '', '', 'http://www.redfin.com/CA/San-Francisco/554-Anderson-St-94110/home/1167343', 'San Francisco MLS', '481273', 'N', 'Y', '37.7364801', '-122.4155901']
# 554 Anderson St
# San Francisco
# CA
# 94110
# Bernal Heights
# 16
# 1830000
# April-9-2019
# 5.0
# 4.0
# 1900
# http://www.redfin.com/CA/San-Francisco/554-Anderson-St-94110/home/1167343
# 37.7364801
# -122.4155901
# 1554793200
# Removed 1 entries...
